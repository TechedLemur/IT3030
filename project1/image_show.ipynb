# %%
# %load_ext autoreload
# %autoreload 2

# %%
from data_generator import DataGenerator
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from config_helper import get_data_from_config_file

# %%
train, test, valid = get_data_from_config_file("./configs/config1.ini")

# %%
def show20Random(dataset):
    plt.figure(figsize=(20,20))

    for i, j in enumerate(np.random.randint(0,len(dataset.data),20 )):
        plt.subplot(5,5,i+1)
        plt.imshow(dataset.data[j].img)

# %%
plt.imshow(DataGenerator.HorizontalBar(20, (7,15), (5,15)))

# %%
show20Random(train)

# %%
df = {}
df['x_train'] = train.x
df['x_test'] = test.x
df['y_train'] = train.y
df['y_test'] = test.y

# %%
import pickle

with open('./dataset.p', 'wb') as file:
            pickle.dump(df, file)

# %%
with open('./dataset.p', 'rb') as file:
    data = pickle.load(file)
    x_train, y_train = data['x_train'], data['y_train']
    x_test, y_test = data['x_test'], data['y_test']
